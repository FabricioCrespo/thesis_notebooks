# %% [markdown]
# # Clone the repository to get the annotations

# %%
# !git clone https://github.com/borutb-fri/FMLD.git
# Out:
# Cloning into 'FMLD'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 251 (delta 19), reused 0 (delta 0), pack-reused 214
# Receiving objects: 100% (251/251), 11.91 MiB | 31.12 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# %cd FMLD/
# Out:
# /content/FMLD

# %%
# !mkdir annotations

# %%
# !unzip FMLD_annotations.zip -d ./annotations/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./annotations/FMLD_annotations/train/train_00020877.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020878.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020879.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020880.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020881.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020882.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020883.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020884.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020885.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020886.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020887.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020888.xml
#   inflating: ./annotations/FMLD_annotations/train/train_00020889.xml
# ...

# %% [markdown]
# ## Copy annotations to drive.

# %%
# !cp -r /content/FMLD/annotations/FMLD_annotations /content/drive/MyDrive/TESIS/Datasets/FMLD_dataset
